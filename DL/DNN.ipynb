# %% [markdown]
# # DNN
# 神经网络的层数也可是做超参数
# 大写L表示神经网络层数
# n^[l]表示神经元数量 n^[0]=n_x
# a^[l]=g(z^[l])表示l层中的激活函数
# w^[l]=weights for z^[l]
# x=a^[0]
# y_hat=a^[L]
# A^[l]向量化的激活值
# ## forward and backward
# ![image.png](attachment:image.png)
